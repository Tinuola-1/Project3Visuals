# %% [markdown]
# # Clean up for Hotness Metrics by County

# %%
import pandas as pd
df = pd.read_csv("../Dataset/Market_Hotness/Hotness_Metrics_County_History.csv")
# Out:
# /Users/vasavdave/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (0,1) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.drop(labels =[77322], axis=0,inplace = True)
df
# Out:
#       month_date_yyyymm county_fips   county_name  cbsa_code  \
# 0                202108       13045   carroll, ga    12060.0
# 1                202108       22115    vernon, la    22860.0
# 2                202108       18051    gibson, in        NaN
# 3                202108       13047   catoosa, ga    16860.0
# 4                202108       13029     bryan, ga    42340.0
# ...                 ...         ...           ...        ...
# 77317            201708       26105     mason, mi    31220.0
# 77318            201708       38101      ward, nd    33500.0
# 77319            201708       27059    isanti, mn    33460.0
# 77320            201708       24009   calvert, md    47900.0
# 77321            201708       13073  columbia, ga    12260.0
#
#                                          cbsa_title  nielsen_hh_rank  \
# 0                 atlanta-sandy springs-roswell, ga            576.0
# 1                               fort polk south, la            970.0
# 2                                               NaN              NaN
# 3                                chattanooga, tn-ga            806.0
# 4                                      savannah, ga           1273.0
# ...                                             ...              ...
# 77317                                 ludington, mi           1292.0
# 77318                                     minot, nd            729.0
# 77319       minneapolis-st. paul-bloomington, mn-wi           1187.0
# 77320  washington-arlington-alexandria, dc-va-md-wv            680.0
# 77321                augusta-richmond county, ga-sc            465.0
#
#        hotness_rank  hotness_rank_mm  hotness_rank_yy  hotness_score  ...  \
# 0             719.0             94.0            -58.0      52.060875  ...
# 1            1407.0            -82.0            100.0      19.150285  ...
# 2             492.0             15.0            426.0      61.287254  ...
# 3              73.0             -7.0             98.0      88.554217  ...
# 4             917.0            204.0            343.0      45.846544  ...
# ...             ...              ...              ...            ...  ...
# 77317         949.0              NaN              NaN      42.327204  ...
# 77318        1030.0              NaN              NaN      37.920101  ...
# 77319         202.0              NaN              NaN      80.944832  ...
# 77320         801.0              NaN              NaN      50.126823  ...
# 77321        1054.0              NaN              NaN      35.954344  ...
#
#        median_dom_yy_day  median_dom_vs_us  \
# 0                  -13.5              -7.5
# 1                  -39.0               9.0
# 2                  -50.0             -10.0
# 3                  -18.5              -9.5
# 4                  -24.0              -1.0
# ...                  ...               ...
# 77317                NaN              28.5
# 77318                NaN               1.5
# 77319                NaN             -21.0
# 77320                NaN              -3.0
# 77321                NaN               0.5
#
#        ldp_unique_viewers_per_property_mm  ldp_unique_viewers_per_property_yy  \
# 0                               -0.150000                            0.133333
# 1                               -0.074074                            0.785714
# 2                               -0.069767                           -0.183673
# 3                                0.035714                            0.279412
# 4                               -0.111111                            1.105263
# ...                                   ...                                 ...
# 77317                                 NaN                                 NaN
# 77318                                 NaN                                 NaN
# 77319                                 NaN                                 NaN
# 77320                                 NaN                                 NaN
# 77321                                 NaN                                 NaN
#
#        ldp_unique_viewers_per_property_vs_us  median_listing_price  \
# 0                                     0.7312              334500.0
# 1                                     0.5376              202450.0
# 2                                     0.8602              150000.0
# 3                                     1.8710              304900.0
# 4                                     0.8602              389942.5
# ...                                      ...                   ...
# 77317                                 1.2000              169900.0
# 77318                                 0.6000              209900.0
# 77319                                 1.3000              227900.0
# 77320                                 0.8000              347000.0
# 77321                                 0.5000              249949.5
#
#        median_listing_price_mm  median_listing_price_yy  \
# 0                    -0.001493                 0.195070
# 1                     0.306129                 0.397170
# 2                    -0.090358                -0.090358
# 3                    -0.016134                 0.037428
# 4                     0.026164                 0.260318
# ...                        ...                      ...
# 77317                      NaN                      NaN
# 77318                      NaN                      NaN
# 77319                      NaN                      NaN
# 77320                      NaN                      NaN
# 77321                      NaN                      NaN
#
#        median_listing_price_vs_us  quality_flag
# 0                          0.8803           0.0
# 1                          0.5328           0.0
# 2                          0.3947           0.0
# 3                          0.8024           0.0
# 4                          1.0262           0.0
# ...                           ...           ...
# 77317                      0.6090           NaN
# 77318                      0.7523           NaN
# 77319                      0.8168           NaN
# 77320                      1.2437           NaN
# 77321                      0.8959           NaN
#
# [77322 rows x 26 columns]

# %%
for col in df.columns:
    print(col)
# Out:
# month_date_yyyymm
# county_fips
# county_name
# cbsa_code
# cbsa_title
# nielsen_hh_rank
# hotness_rank
# hotness_rank_mm
# hotness_rank_yy
# hotness_score
# supply_score
# demand_score
# median_days_on_market
# median_days_on_market_mm
# median_dom_mm_day
# median_days_on_market_yy
# median_dom_yy_day
# median_dom_vs_us
# ldp_unique_viewers_per_property_mm
# ldp_unique_viewers_per_property_yy
# ldp_unique_viewers_per_property_vs_us
# median_listing_price
# median_listing_price_mm
# median_listing_price_yy
# median_listing_price_vs_us
# quality_flag

# %%
#df.groupby(["hotness_rank","month_date_yyyymm"])
#df.head()

# %%
#df.sort_values(by=['hotness_rank'], ascending=True, inplace=False)
#df.head()

# %%
df.to_csv("../Output/Hotness_Metrics_By_County.csv")

# %% [markdown]
# # Clean up for Hotness Metrics by Metro

# %%
metro_hotness = pd.read_csv("../Dataset/Market_Hotness/Hotness_Metrics_Metro_History.csv")
for col in metro_hotness.columns:
    print(col)
# Out:
# month_date_yyyymm
# cbsa_code
# cbsa_title
# nielsen_hh_rank
# hotness_rank
# hotness_rank_mm
# hotness_rank_yy
# hotness_score
# supply_score
# demand_score
# median_days_on_market
# median_days_on_market_mm
# median_dom_mm_day
# median_days_on_market_yy
# median_dom_yy_day
# median_dom_vs_us
# ldp_unique_viewers_per_property_mm
# ldp_unique_viewers_per_property_yy
# ldp_unique_viewers_per_property_vs_us
# median_listing_price
# median_listing_price_mm
# median_listing_price_yy
# median_listing_price_vs_us
# quality_flag

# %%
metro_hotness
# Out:
#                                        month_date_yyyymm  \
# 0                                                 202108
# 1                                                 202108
# 2                                                 202108
# 3                                                 202108
# 4                                                 202108
# ...                                                  ...
# 14696                                             201708
# 14697                                             201708
# 14698                                             201708
# 14699                                             201708
# 14700  quality_flag = 1:  year-over-year figures may ...
#
#                                                cbsa_code  \
# 0                                                  17780
# 1                                                  40420
# 2                                                  22900
# 3                                                  14010
# 4                                                  46060
# ...                                                  ...
# 14696                                              41500
# 14697                                              44300
# 14698                                              20100
# 14699                                              45500
# 14700   please contact economics@realtor.com for more...
#
#                       cbsa_title  nielsen_hh_rank  hotness_rank  \
# 0      college station-bryan, tx            193.0         218.0
# 1                   rockford, il            154.0          62.0
# 2              fort smith, ar-ok            170.0         157.0
# 3                bloomington, il            224.0         266.0
# 4                     tucson, az             51.0         201.0
# ...                          ...              ...           ...
# 14696                salinas, ca            150.0          71.0
# 14697          state college, pa            270.0         122.0
# 14698                  dover, de            251.0         237.0
# 14699           texarkana, tx-ar            285.0         225.0
# 14700                        NaN              NaN           NaN
#
#        hotness_rank_mm  hotness_rank_yy  hotness_score  supply_score  \
# 0                 15.0             74.0      36.120401     51.839465
# 1                 -5.0             -3.0      68.060201     78.929766
# 2                -44.0            112.0      48.160535     49.832776
# 3                -11.0            -13.0      21.739130      2.341137
# 4                  9.0            -37.0      40.468227     65.551839
# ...                ...              ...            ...           ...
# 14696              NaN              NaN      71.571906     48.160535
# 14697              NaN              NaN      57.023411     28.428094
# 14698              NaN              NaN      28.093645      8.026756
# 14699              NaN              NaN      30.602007     39.130435
# 14700              NaN              NaN            NaN           NaN
#
#        demand_score  ...  median_dom_yy_day  median_dom_vs_us  \
# 0         20.401338  ...              -42.0              -3.0
# 1         57.190635  ...              -15.5              -9.5
# 2         46.488294  ...              -36.5              -2.5
# 3         41.137124  ...               -2.0              32.0
# 4         15.384615  ...              -13.0              -6.0
# ...             ...  ...                ...               ...
# 14696     94.983278  ...                NaN              -2.5
# 14697     85.618729  ...                NaN              11.0
# 14698     48.160535  ...                NaN              26.5
# 14699     22.073579  ...                NaN               2.5
# 14700           NaN  ...                NaN               NaN
#
#        ldp_unique_viewers_per_property_mm  ldp_unique_viewers_per_property_yy  \
# 0                               -0.107143                            1.272727
# 1                               -0.187500                           -0.048780
# 2                               -0.100000                            0.636364
# 3                               -0.128205                            0.307692
# 4                               -0.153846                           -0.043478
# ...                                   ...                                 ...
# 14696                                 NaN                                 NaN
# 14697                                 NaN                                 NaN
# 14698                                 NaN                                 NaN
# 14699                                 NaN                                 NaN
# 14700                                 NaN                                 NaN
#
#        ldp_unique_viewers_per_property_vs_us  median_listing_price  \
# 0                                     0.6757              299000.0
# 1                                     1.0541              167450.0
# 2                                     0.9730              203499.5
# 3                                     0.9189              130000.0
# 4                                     0.5946              359700.0
# ...                                      ...                   ...
# 14696                                 2.0000              890001.0
# 14697                                 1.5556              253200.0
# 14698                                 1.0000              247900.0
# 14699                                 0.7778              140950.0
# 14700                                    NaN                   NaN
#
#        median_listing_price_mm  median_listing_price_yy  \
# 0                    -0.092564                 0.128302
# 1                    -0.009172                -0.014420
# 2                    -0.030955                 0.023125
# 3                    -0.071429                -0.037037
# 4                     0.027714                 0.107110
# ...                        ...                      ...
# 14696                      NaN                      NaN
# 14697                      NaN                      NaN
# 14698                      NaN                      NaN
# 14699                      NaN                      NaN
# 14700                      NaN                      NaN
#
#        median_listing_price_vs_us  quality_flag
# 0                          0.7868           0.0
# 1                          0.4407           0.0
# 2                          0.5355           0.0
# 3                          0.3421           0.0
# 4                          0.9466           0.0
# ...                           ...           ...
# 14696                      3.1900           NaN
# 14697                      0.9075           NaN
# 14698                      0.8885           NaN
# 14699                      0.5052           NaN
# 14700                         NaN           NaN
#
# [14701 rows x 24 columns]

# %%
metro_hotness.to_csv("../Output/Hotness_Metrics_By_Metro.csv")

# %% [markdown]
# # Clean up for Hotness Metrics by Zip

# %%
zip_hotness = pd.read_csv("../Dataset/Market_Hotness/Hotness_Metrics_zip_History.csv")
for col in zip_hotness.columns:
    print(col)
# Out:
# month_date_yyyymm
# postal_code
# zip_name
# nielsen_hh_rank
# hotness_rank
# hotness_rank_mm
# hotness_rank_yy
# hotness_score
# supply_score
# demand_score
# median_days_on_market
# median_days_on_market_mm
# median_dom_mm_day
# median_days_on_market_yy
# median_dom_yy_day
# median_dom_vs_us
# ldp_unique_viewers_per_property_mm
# ldp_unique_viewers_per_property_yy
# ldp_unique_viewers_per_property_vs_us
# median_listing_price
# median_listing_price_mm
# median_listing_price_yy
# median_listing_price_vs_us

# %%
zip_hotness
# Out:
#         month_date_yyyymm  postal_code         zip_name  nielsen_hh_rank  \
# 0                  202108        34219      parrish, fl             5530
# 1                  202108        32824      orlando, fl             2436
# 2                  202108        54646      necedah, wi            14327
# 3                  202108        91354     valencia, ca             4140
# 4                  202108        93230      hanford, ca              412
# ...                   ...          ...              ...              ...
# 716991             201708        17019    dillsburg, pa             6479
# 716992             201708        28104     matthews, nc             4019
# 716993             201708        27882  spring hope, nc            10921
# 716994             201708         5474   north hero, vt            23366
# 716995             201708        51566      red oak, ia            10986
#
#         hotness_rank  hotness_rank_mm  hotness_rank_yy  hotness_score  \
# 0               1824            433.0           8449.0      75.407760
# 1               1315            589.0           2551.0      79.001804
# 2               9005          -2246.0           3115.0      45.243121
# 3               5005           -707.0          -2916.0      60.430978
# 4               1382           -325.0             92.0      78.527843
# ...              ...              ...              ...            ...
# 716991          4979              NaN              NaN      66.253580
# 716992          5684              NaN              NaN      63.014981
# 716993          7569              NaN              NaN      54.020709
# 716994         12594              NaN              NaN      25.633399
# 716995         13803              NaN              NaN      16.589557
#
#         supply_score  demand_score  ...  median_days_on_market_yy  \
# 0          72.456538     78.358982  ...                 -0.463636
# 1          69.777795     88.225813  ...                 -0.340426
# 2          24.588402     65.897839  ...                 -0.776846
# 3          78.098016     42.763941  ...                 -0.337500
# 4          80.903404     76.152282  ...                 -0.305556
# ...              ...           ...  ...                       ...
# 716991     46.552104     85.955056  ...                       NaN
# 716992     61.772050     64.257913  ...                       NaN
# 716993     77.799809     30.241610  ...                       NaN
# 716994     20.881986     30.384813  ...                       NaN
# 716995     18.179482     14.999633  ...                       NaN
#
#         median_dom_yy_day  median_dom_vs_us  \
# 0                   -25.5              -9.5
# 1                   -16.0              -8.0
# 2                  -231.5              27.5
# 3                   -13.5             -12.5
# 4                   -11.0             -14.0
# ...                   ...               ...
# 716991                NaN              10.5
# 716992                NaN              -4.5
# 716993                NaN             -19.5
# 716994                NaN              49.5
# 716995                NaN              57.0
#
#         ldp_unique_viewers_per_property_mm  \
# 0                                -0.223776
# 1                                -0.013793
# 2                                -0.092784
# 3                                -0.200000
# 4                                -0.208955
# ...                                    ...
# 716991                                 NaN
# 716992                                 NaN
# 716993                                 NaN
# 716994                                 NaN
# 716995                                 NaN
#
#         ldp_unique_viewers_per_property_yy  \
# 0                                 2.083333
# 1                                 0.588889
# 2                                 0.294118
# 3                                -0.469027
# 4                                -0.138211
# ...                                    ...
# 716991                                 NaN
# 716992                                 NaN
# 716993                                 NaN
# 716994                                 NaN
# 716995                                 NaN
#
#         ldp_unique_viewers_per_property_vs_us  median_listing_price  \
# 0                                      1.7077              426512.5
# 1                                      2.2000              377500.0
# 2                                      1.3538              279000.0
# 3                                      0.9231              789500.0
# 4                                      1.6308              357000.0
# ...                                       ...                   ...
# 716991                                 2.0000              277575.0
# 716992                                 1.2222              466999.5
# 716993                                 0.6667              127990.0
# 716994                                 0.6667              285999.0
# 716995                                 0.4444               87000.0
#
#         median_listing_price_mm  median_listing_price_yy  \
# 0                      0.074366                 0.384668
# 1                      0.110294                 0.161538
# 2                      0.000000                -0.418629
# 3                      0.032026                 0.178358
# 4                      0.034783                 0.298182
# ...                         ...                      ...
# 716991                      NaN                      NaN
# 716992                      NaN                      NaN
# 716993                      NaN                      NaN
# 716994                      NaN                      NaN
# 716995                      NaN                      NaN
#
#         median_listing_price_vs_us
# 0                           1.1224
# 1                           0.9934
# 2                           0.7342
# 3                           2.0776
# 4                           0.9395
# ...                            ...
# 716991                      0.9949
# 716992                      1.6738
# 716993                      0.4587
# 716994                      1.0251
# 716995                      0.3118
#
# [716996 rows x 23 columns]

# %%
zip_hotness.to_csv("../Output/Hotness_Metrics_By_Zip.csv")

# %% [markdown]
# # Monthly Metrics by Country

# %%
monthly_country = pd.read_csv("../Dataset/Monthly_Inventory/Historical/Metrics_Country_History.csv")
monthly_country
# Out:
#     month_date_yyyymm        country  median_listing_price  \
# 0              202108  United States              380000.0
# 1              202107  United States              385000.0
# 2              202106  United States              385000.0
# 3              202105  United States              379900.0
# 4              202104  United States              375000.0
# ..                ...            ...                   ...
# 57             201611  United States              255000.0
# 58             201610  United States              258048.0
# 59             201609  United States              257280.0
# 60             201608  United States              259000.0
# 61             201607  United States              259900.0
#
#     median_listing_price_mm  median_listing_price_yy  active_listing_count  \
# 0                   -0.0130                   0.0860                640716
# 1                    0.0000                   0.1032                606086
# 2                    0.0134                   0.1273                548864
# 3                    0.0131                   0.1516                504436
# 4                    0.0137                   0.1719                491969
# ..                      ...                      ...                   ...
# 57                      NaN                      NaN               1449677
# 58                      NaN                      NaN               1522232
# 59                      NaN                      NaN               1562584
# 60                      NaN                      NaN               1581909
# 61                      NaN                      NaN               1582557
#
#     active_listing_count_mm  active_listing_count_yy  median_days_on_market  \
# 0                    0.0571                  -0.2581                   39.0
# 1                    0.1043                  -0.3345                   38.0
# 2                    0.0881                  -0.4305                   37.0
# 3                    0.0253                  -0.5088                   39.0
# 4                   -0.0023                  -0.5296                   43.0
# ..                      ...                      ...                    ...
# 57                      NaN                      NaN                   82.5
# 58                      NaN                      NaN                   79.0
# 59                      NaN                      NaN                   78.0
# 60                      NaN                      NaN                   73.0
# 61                      NaN                      NaN                   69.0
#
#     median_days_on_market_mm  ...  median_square_feet_yy  \
# 0                   0.026316  ...                -0.0628
# 1                   0.027027  ...                -0.0705
# 2                  -0.051282  ...                -0.0777
# 3                  -0.093023  ...                -0.0778
# 4                  -0.203704  ...                -0.0742
# ..                       ...  ...                    ...
# 57                       NaN  ...                    NaN
# 58                       NaN  ...                    NaN
# 59                       NaN  ...                    NaN
# 60                       NaN  ...                    NaN
# 61                       NaN  ...                    NaN
#
#     average_listing_price  average_listing_price_mm  average_listing_price_yy  \
# 0             703919.5098                   -0.0121                    0.1016
# 1             712562.4963                   -0.0319                    0.1588
# 2             736035.0593                   -0.0116                    0.2321
# 3             744682.1304                   -0.0273                    0.3063
# 4             765602.1531                   -0.0122                    0.3700
# ..                    ...                       ...                       ...
# 57            449150.2465                       NaN                       NaN
# 58            445484.5253                       NaN                       NaN
# 59            441384.8244                       NaN                       NaN
# 60            441331.5800                       NaN                       NaN
# 61            444871.7801                       NaN                       NaN
#
#     total_listing_count  total_listing_count_mm  total_listing_count_yy  \
# 0               1321512                  0.0239                 -0.1380
# 1               1290610                  0.0247                 -0.1735
# 2               1259443                  0.0441                 -0.2028
# 3               1206227                  0.0426                 -0.2076
# 4               1156938                  0.0415                 -0.2189
# ..                  ...                     ...                     ...
# 57              1787258                     NaN                     NaN
# 58              1880774                     NaN                     NaN
# 59              1937772                     NaN                     NaN
# 60              1980635                     NaN                     NaN
# 61              2004410                     NaN                     NaN
#
#     pending_ratio  pending_ratio_mm  pending_ratio_yy
# 0        1.062555           -0.0669            0.2873
# 1        1.129417           -0.1652            0.4149
# 2        1.294636           -0.0966            0.6555
# 3        1.391239            0.0396            0.9090
# 4        1.351648            0.0988            0.9354
# ..            ...               ...               ...
# 57       0.232866               NaN               NaN
# 58       0.235537               NaN               NaN
# 59       0.240107               NaN               NaN
# 60       0.252054               NaN               NaN
# 61       0.266564               NaN               NaN
#
# [62 rows x 38 columns]

# %%
for col in monthly_country.columns:
    print(col)
# Out:
# month_date_yyyymm
# country
# median_listing_price
# median_listing_price_mm
# median_listing_price_yy
# active_listing_count
# active_listing_count_mm
# active_listing_count_yy
# median_days_on_market
# median_days_on_market_mm
# median_days_on_market_yy
# new_listing_count
# new_listing_count_mm
# new_listing_count_yy
# price_increased_count
# price_increased_count_mm
# price_increased_count_yy
# price_reduced_count
# price_reduced_count_mm
# price_reduced_count_yy
# pending_listing_count
# pending_listing_count_mm
# pending_listing_count_yy
# median_listing_price_per_square_foot
# median_listing_price_per_square_foot_mm
# median_listing_price_per_square_foot_yy
# median_square_feet
# median_square_feet_mm
# median_square_feet_yy
# average_listing_price
# average_listing_price_mm
# average_listing_price_yy
# total_listing_count
# total_listing_count_mm
# total_listing_count_yy
# pending_ratio
# pending_ratio_mm
# pending_ratio_yy

# %%
monthly_country.to_csv("../Output/Monthly_Metrics_By_Country.csv")

# %% [markdown]
# # Monthly Metrics by County

# %%
monthly_county = pd.read_csv("../Dataset/Monthly_Inventory/Historical/Metrics_County_History.csv")
monthly_county
# Out:
#        month_date_yyyymm  county_fips      county_name  median_listing_price  \
# 0                 202108        41029      jackson, or              522494.5
# 1                 202108         6037  los angeles, ca              984000.0
# 2                 202108         5069    jefferson, ar              102450.0
# 3                 202108        49045       tooele, ut              487500.0
# 4                 202108        31153        sarpy, ne              387000.0
# ...                  ...          ...              ...                   ...
# 61995             201607        42039     crawford, pa              118000.0
# 61996             201607        13045      carroll, ga              180000.0
# 61997             201607         9011   new london, ct              285000.0
# 61998             201607        42003    allegheny, pa              169900.0
# 61999             201607        42011        berks, pa              185000.0
#
#        median_listing_price_mm  median_listing_price_yy  active_listing_count  \
# 0                      -0.0048                   0.0908                   454
# 1                      -0.0160                  -0.0629                 11795
# 2                       0.0255                   0.3151                    89
# 3                      -0.0150                   0.2420                   107
# 4                       0.0320                   0.1078                   231
# ...                        ...                      ...                   ...
# 61995                      NaN                      NaN                   563
# 61996                      NaN                      NaN                  1084
# 61997                      NaN                      NaN                  2128
# 61998                      NaN                      NaN                  5015
# 61999                      NaN                      NaN                  2120
#
#        active_listing_count_mm  active_listing_count_yy  \
# 0                       0.0784                  -0.1303
# 1                       0.0136                  -0.0868
# 2                       0.1558                  -0.1759
# 3                       0.2738                   0.0808
# 4                       0.0596                  -0.3362
# ...                        ...                      ...
# 61995                      NaN                      NaN
# 61996                      NaN                      NaN
# 61997                      NaN                      NaN
# 61998                      NaN                      NaN
# 61999                      NaN                      NaN
#
#        median_days_on_market  ...  median_square_feet_yy  \
# 0                       42.5  ...                -0.0946
# 1                       49.0  ...                -0.0522
# 2                       38.5  ...                 0.1059
# 3                       17.5  ...                -0.0445
# 4                       40.5  ...                -0.0344
# ...                      ...  ...                    ...
# 61995                   82.0  ...                    NaN
# 61996                   52.0  ...                    NaN
# 61997                   79.0  ...                    NaN
# 61998                   70.0  ...                    NaN
# 61999                   83.0  ...                    NaN
#
#        average_listing_price  average_listing_price_mm  \
# 0               7.030042e+05                   -0.0096
# 1               2.453058e+06                   -0.0262
# 2               1.317856e+05                    0.0273
# 3               5.124959e+05                    0.0103
# 4               4.009027e+05                    0.0008
# ...                      ...                       ...
# 61995           1.586993e+05                       NaN
# 61996           2.423968e+05                       NaN
# 61997           4.112547e+05                       NaN
# 61998           2.756118e+05                       NaN
# 61999           2.340682e+05                       NaN
#
#        average_listing_price_yy  total_listing_count  total_listing_count_mm  \
# 0                       -0.0048                 1019                 -0.0039
# 1                        0.0066                22901                  0.0090
# 2                        0.0554                  174                  0.5818
# 3                        0.3007                  341                  0.0965
# 4                        0.0855                 1078                 -0.0253
# ...                         ...                  ...                     ...
# 61995                       NaN                  623                     NaN
# 61996                       NaN                 1381                     NaN
# 61997                       NaN                 2486                     NaN
# 61998                       NaN                 7679                     NaN
# 61999                       NaN                 3047                     NaN
#
#        total_listing_count_yy  pending_ratio  pending_ratio_mm  \
# 0                     -0.1572       1.244493           -0.1854
# 1                     -0.0740       0.941585           -0.0087
# 2                      0.3594       0.955056            0.5265
# 3                     -0.0606       2.186916           -0.5155
# 4                     -0.0650       3.666667           -0.4067
# ...                       ...            ...               ...
# 61995                     NaN       0.106572               NaN
# 61996                     NaN       0.273985               NaN
# 61997                     NaN       0.168233               NaN
# 61998                     NaN       0.531206               NaN
# 61999                     NaN       0.437264               NaN
#
#        pending_ratio_yy
# 0               -0.0716
# 1                0.0269
# 2                0.7699
# 3               -0.4798
# 4                1.3534
# ...                 ...
# 61995               NaN
# 61996               NaN
# 61997               NaN
# 61998               NaN
# 61999               NaN
#
# [62000 rows x 39 columns]

# %%
for col in monthly_county.columns:
    print(col)
# Out:
# month_date_yyyymm
# county_fips
# county_name
# median_listing_price
# median_listing_price_mm
# median_listing_price_yy
# active_listing_count
# active_listing_count_mm
# active_listing_count_yy
# median_days_on_market
# median_days_on_market_mm
# median_days_on_market_yy
# new_listing_count
# new_listing_count_mm
# new_listing_count_yy
# price_increased_count
# price_increased_count_mm
# price_increased_count_yy
# price_reduced_count
# price_reduced_count_mm
# price_reduced_count_yy
# pending_listing_count
# pending_listing_count_mm
# pending_listing_count_yy
# median_listing_price_per_square_foot
# median_listing_price_per_square_foot_mm
# median_listing_price_per_square_foot_yy
# median_square_feet
# median_square_feet_mm
# median_square_feet_yy
# average_listing_price
# average_listing_price_mm
# average_listing_price_yy
# total_listing_count
# total_listing_count_mm
# total_listing_count_yy
# pending_ratio
# pending_ratio_mm
# pending_ratio_yy

# %%
monthly_county.set_index(keys= 'month_date_yyyymm', drop=True, inplace=True)

# %%
monthly_county
# Out:
#                    county_fips      county_name  median_listing_price  \
# month_date_yyyymm
# 202108                   41029      jackson, or              522494.5
# 202108                    6037  los angeles, ca              984000.0
# 202108                    5069    jefferson, ar              102450.0
# 202108                   49045       tooele, ut              487500.0
# 202108                   31153        sarpy, ne              387000.0
# ...                        ...              ...                   ...
# 201607                   42039     crawford, pa              118000.0
# 201607                   13045      carroll, ga              180000.0
# 201607                    9011   new london, ct              285000.0
# 201607                   42003    allegheny, pa              169900.0
# 201607                   42011        berks, pa              185000.0
#
#                    median_listing_price_mm  median_listing_price_yy  \
# month_date_yyyymm
# 202108                             -0.0048                   0.0908
# 202108                             -0.0160                  -0.0629
# 202108                              0.0255                   0.3151
# 202108                             -0.0150                   0.2420
# 202108                              0.0320                   0.1078
# ...                                    ...                      ...
# 201607                                 NaN                      NaN
# 201607                                 NaN                      NaN
# 201607                                 NaN                      NaN
# 201607                                 NaN                      NaN
# 201607                                 NaN                      NaN
#
#                    active_listing_count  active_listing_count_mm  \
# month_date_yyyymm
# 202108                              454                   0.0784
# 202108                            11795                   0.0136
# 202108                               89                   0.1558
# 202108                              107                   0.2738
# 202108                              231                   0.0596
# ...                                 ...                      ...
# 201607                              563                      NaN
# 201607                             1084                      NaN
# 201607                             2128                      NaN
# 201607                             5015                      NaN
# 201607                             2120                      NaN
#
#                    active_listing_count_yy  median_days_on_market  \
# month_date_yyyymm
# 202108                             -0.1303                   42.5
# 202108                             -0.0868                   49.0
# 202108                             -0.1759                   38.5
# 202108                              0.0808                   17.5
# 202108                             -0.3362                   40.5
# ...                                    ...                    ...
# 201607                                 NaN                   82.0
# 201607                                 NaN                   52.0
# 201607                                 NaN                   79.0
# 201607                                 NaN                   70.0
# 201607                                 NaN                   83.0
#
#                    median_days_on_market_mm  ...  median_square_feet_yy  \
# month_date_yyyymm                            ...
# 202108                             0.089744  ...                -0.0946
# 202108                             0.000000  ...                -0.0522
# 202108                             0.013158  ...                 0.1059
# 202108                             0.029412  ...                -0.0445
# 202108                             0.065789  ...                -0.0344
# ...                                     ...  ...                    ...
# 201607                                  NaN  ...                    NaN
# 201607                                  NaN  ...                    NaN
# 201607                                  NaN  ...                    NaN
# 201607                                  NaN  ...                    NaN
# 201607                                  NaN  ...                    NaN
#
#                    average_listing_price  average_listing_price_mm  \
# month_date_yyyymm
# 202108                      7.030042e+05                   -0.0096
# 202108                      2.453058e+06                   -0.0262
# 202108                      1.317856e+05                    0.0273
# 202108                      5.124959e+05                    0.0103
# 202108                      4.009027e+05                    0.0008
# ...                                  ...                       ...
# 201607                      1.586993e+05                       NaN
# 201607                      2.423968e+05                       NaN
# 201607                      4.112547e+05                       NaN
# 201607                      2.756118e+05                       NaN
# 201607                      2.340682e+05                       NaN
#
#                    average_listing_price_yy  total_listing_count  \
# month_date_yyyymm
# 202108                              -0.0048                 1019
# 202108                               0.0066                22901
# 202108                               0.0554                  174
# 202108                               0.3007                  341
# 202108                               0.0855                 1078
# ...                                     ...                  ...
# 201607                                  NaN                  623
# 201607                                  NaN                 1381
# 201607                                  NaN                 2486
# 201607                                  NaN                 7679
# 201607                                  NaN                 3047
#
#                    total_listing_count_mm  total_listing_count_yy  \
# month_date_yyyymm
# 202108                            -0.0039                 -0.1572
# 202108                             0.0090                 -0.0740
# 202108                             0.5818                  0.3594
# 202108                             0.0965                 -0.0606
# 202108                            -0.0253                 -0.0650
# ...                                   ...                     ...
# 201607                                NaN                     NaN
# 201607                                NaN                     NaN
# 201607                                NaN                     NaN
# 201607                                NaN                     NaN
# 201607                                NaN                     NaN
#
#                    pending_ratio  pending_ratio_mm  pending_ratio_yy
# month_date_yyyymm
# 202108                  1.244493           -0.1854           -0.0716
# 202108                  0.941585           -0.0087            0.0269
# 202108                  0.955056            0.5265            0.7699
# 202108                  2.186916           -0.5155           -0.4798
# 202108                  3.666667           -0.4067            1.3534
# ...                          ...               ...               ...
# 201607                  0.106572               NaN               NaN
# 201607                  0.273985               NaN               NaN
# 201607                  0.168233               NaN               NaN
# 201607                  0.531206               NaN               NaN
# 201607                  0.437264               NaN               NaN
#
# [62000 rows x 38 columns]

# %%
monthly_county.to_csv("../Output/Monthly_Metrics_By_County.csv")

# %% [markdown]
# # Monthly Metrics by Metro

# %%
monthly_metro = pd.read_csv("../Dataset/Monthly_Inventory/Historical/Metrics_Metro_History.csv")
monthly_metro
# Out:
#        month_date_yyyymm  cbsa_code                             cbsa_title  \
# 0                 202108      35620  new york-newark-jersey city, ny-nj-pa
# 1                 202108      31080     los angeles-long beach-anaheim, ca
# 2                 202108      16980     chicago-naperville-elgin, il-in-wi
# 3                 202108      19100        dallas-fort worth-arlington, tx
# 4                 202108      26420   houston-the woodlands-sugar land, tx
# ...                  ...        ...                                    ...
# 56849             201607      46900                             vernon, tx
# 56850             201607      18780                              craig, co
# 56851             201607      29500                             lamesa, tx
# 56852             201607      49820                             zapata, tx
# 56853             201607      37780                              pecos, tx
#
#        HouseholdRank  median_listing_price  median_listing_price_mm  \
# 0                  1              602500.0                   0.0058
# 1                  2              974500.0                  -0.0245
# 2                  3              340950.0                  -0.0256
# 3                  4              396495.0                   0.0038
# 4                  5              364217.5                  -0.0021
# ...              ...                   ...                      ...
# 56849            913              139000.0                      NaN
# 56850            914              175000.0                      NaN
# 56851            915              101900.0                      NaN
# 56852            916              128000.0                      NaN
# 56853            917              169900.0                      NaN
#
#        median_listing_price_yy  active_listing_count  active_listing_count_mm  \
# 0                      -0.0267                 64288                   0.0326
# 1                      -0.0245                 14288                   0.0092
# 2                      -0.0231                 22164                   0.0445
# 3                       0.1014                  9110                   0.1037
# 4                       0.1054                 16357                   0.0924
# ...                        ...                   ...                      ...
# 56849                      NaN                     3                      NaN
# 56850                      NaN                   186                      NaN
# 56851                      NaN                    11                      NaN
# 56852                      NaN                    27                      NaN
# 56853                      NaN                     5                      NaN
#
#        active_listing_count_yy  ...  median_square_feet_yy  \
# 0                      -0.1286  ...                -0.1298
# 1                      -0.1759  ...                -0.0626
# 2                      -0.1683  ...                -0.0876
# 3                      -0.3734  ...                -0.0806
# 4                      -0.2516  ...                -0.0694
# ...                        ...  ...                    ...
# 56849                      NaN  ...                    NaN
# 56850                      NaN  ...                    NaN
# 56851                      NaN  ...                    NaN
# 56852                      NaN  ...                    NaN
# 56853                      NaN  ...                    NaN
#
#        average_listing_price  average_listing_price_mm  \
# 0               1.313384e+06                    0.0824
# 1               2.372414e+06                   -0.0214
# 2               4.994379e+05                   -0.0403
# 3               5.679595e+05                   -0.0214
# 4               5.265473e+05                   -0.0340
# ...                      ...                       ...
# 56849           1.728000e+05                       NaN
# 56850           2.134051e+05                       NaN
# 56851           1.304111e+05                       NaN
# 56852           1.290893e+05                       NaN
# 56853           1.019750e+05                       NaN
#
#        average_listing_price_yy  total_listing_count  total_listing_count_mm  \
# 0                        0.1175                97648                  0.0384
# 1                        0.0550                28984                  0.0038
# 2                       -0.0025                44173                 -0.0078
# 3                        0.0674                23662                  0.0466
# 4                        0.0694                32162                  0.0197
# ...                         ...                  ...                     ...
# 56849                       NaN                    5                     NaN
# 56850                       NaN                  208                     NaN
# 56851                       NaN                   13                     NaN
# 56852                       NaN                   27                     NaN
# 56853                       NaN                    6                     NaN
#
#        total_listing_count_yy  pending_ratio  pending_ratio_mm  \
# 0                     -0.0796       0.518915            0.0085
# 1                     -0.1342       1.028555           -0.0108
# 2                     -0.1497       0.993007           -0.1051
# 3                     -0.2174       1.597366           -0.1417
# 4                     -0.1462       0.966253           -0.1403
# ...                       ...            ...               ...
# 56849                     NaN       0.666667               NaN
# 56850                     NaN       0.118280               NaN
# 56851                     NaN       0.181818               NaN
# 56852                     NaN       0.000000               NaN
# 56853                     NaN       0.200000               NaN
#
#        pending_ratio_yy
# 0                0.0809
# 1                0.0978
# 2                0.0437
# 3                0.5176
# 4                0.2428
# ...                 ...
# 56849               NaN
# 56850               NaN
# 56851               NaN
# 56852               NaN
# 56853               NaN
#
# [56854 rows x 40 columns]

# %%
.reset_index(drop=True, inplace=True)

# %%
for col in monthly_metro.columns:
    print(col)
# Out:
# month_date_yyyymm
# cbsa_code
# cbsa_title
# HouseholdRank
# median_listing_price
# median_listing_price_mm
# median_listing_price_yy
# active_listing_count
# active_listing_count_mm
# active_listing_count_yy
# median_days_on_market
# median_days_on_market_mm
# median_days_on_market_yy
# new_listing_count
# new_listing_count_mm
# new_listing_count_yy
# price_increased_count
# price_increased_count_mm
# price_increased_count_yy
# price_reduced_count
# price_reduced_count_mm
# price_reduced_count_yy
# pending_listing_count
# pending_listing_count_mm
# pending_listing_count_yy
# median_listing_price_per_square_foot
# median_listing_price_per_square_foot_mm
# median_listing_price_per_square_foot_yy
# median_square_feet
# median_square_feet_mm
# median_square_feet_yy
# average_listing_price
# average_listing_price_mm
# average_listing_price_yy
# total_listing_count
# total_listing_count_mm
# total_listing_count_yy
# pending_ratio
# pending_ratio_mm
# pending_ratio_yy

# %%
monthly_metro.to_csv("../Output/Monthly_Metrics_By_Metro.csv")

# %% [markdown]
# # Monthly Metrics by State

# %%
monthly_state = pd.read_csv("../Dataset/Monthly_Inventory/Historical/Metrics_State_History.csv")
monthly_state
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Metrics_State_History
# month_date_yyyymm state        state_id median_listing_price median_listing_price_mm median_listing_price_yy active_listing_count active_listing_count_mm active_listing_count_yy median_days_on_market median_days_on_market_mm median_days_on_market_yy new_listing_count new_listing_count_mm new_listing_count_yy price_increased_count price_increased_count_mm price_increased_count_yy price_reduced_count price_reduced_count_mm price_reduced_count_yy pending_listing_count pending_listing_count_mm pending_listing_count_yy median_listing_price_per_square_foot median_listing_price_per_square_foot_mm median_listing_price_per_square_foot_yy median_square_feet median_square_feet_mm median_square_feet_yy average_listing_price average_listing_price_mm average_listing_price_yy total_listing_count total_listing_count_mm total_listing_count_yy pending_ratio pending_ratio_mm      pending_ratio_yy
# 202108            vermont      vt       350000               0                       0.0769                  1686                 -0.0035                 -0.4115                 54.5                  0.184782609              -0.263513514             820               -0.1734              -0.2293              24                    0                        -0.5385                  360                 0.0345                 -0.2035                1135                  0.0161                   -0.3167                  189.9454365                          -0.0107                                 0.1872                                  1954               0.0198                -0.0422               545331.1847           0.013                    0.1247                   2821                0.0043                 -0.3767                0.673190985   0.013                           0.0934
#                   nebraska     ne       255000               -0.0189                 0.02                    3072                 0.0431                  -0.2209                 45.5                  0.011111111              -0.228813559             2036              -0.0414              0.0538               56                    -0.2632                  -0.7846                  700                 0.1364                 -0.0838                4813                  -0.0378                  0.0105                   129.4752103                          -0.0072                                 0.102                                   1883.5             -0.0149               -0.0817               329148.3166           -0.0321                  0.0766                   7885                -0.0078                -0.0943                1.566731771   -0.1317                         0.3588
#                   kansas       ks       215000               -0.0223                 0                       4363                 0.047                   -0.2257                 41                    0.025                    -0.316666667             2904              -0.0176              0.063                160                   0.1765                   -0.0244                  1452                0.1273                 -0.062                 6379                  -0.038                   0.035                    111.9199309                          5E-04                                   0.1184                                  1874               -0.0032               -0.085                303980.0402           -0.017                   -0.0217                  10742               -0.0052                -0.0895                1.462067385   -0.1292                         0.3684
#                   pennsylvania pa       269900               -0.0185                 0.0381                  22110                0.036                   -0.1276                 43.5                  0.06097561               -0.194444444             14020             -0.055               0.095                536                   -0.0694                  -0.4704                  7492                0.0558                 0.0534                 25397                 -0.0188                  0.7581                   146.9375                             -0.0093                                 0.1456                                  1612.5             -0.0119               -0.062                386871.3629           -0.0359                  0.0107                   47507               0.006                  0.1939                 1.148665762   -0.0641                         0.5787
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# 201801            montana      mt       335150               7E-04                   0.0312                  6575                 -0.0968                 -0.0077                 142.5                 0.08778626               0.104651163              1168              0.2167               0.0896               36                    0.2857                   -0.1                     512                 0.113                  0.0492                 4408                  2.425                    4.279                    156.451865                           0.0013                                  0.2648                                  2195               0.0018                0.1744                617756.3444           0.01                     0.03                     10983               0.282                  0.4721                 0.670418251   0.4936                          0.5444
#                   hawaii       hi       682400               -0.0023                 -0.0073                 5425                 0.0061                  -0.0982                 87                    -0.011363636             -0.02247191              1740              0.2358               -0.0136              88                    0.2222                   0.4667                   840                 0.1475                 0.0606                 2536                  2.9812                   1.7094                   507.5918964                          0.0118                                  0.0501                                  1360               0.0059                -0.0116               1382679.908           0.0214                   0.0403                   7961                0.3205                 0.1451                 0.467465438   0.3493                          0.3119
#                   maryland     md       299990               0                       0.038                   17934                -0.1058                 -0.1298                 85                    0.103896104              -0.076086957             5612              0.1538               -0.1371              496                   0.2525                   -0.1014                  3920                0.0757                 -0.1358                12044                 2.3567                   2.3363                   102.34375                            0.0661                                  -0.3394                                 1022               0.0139                -0.3821               407669.7888           -0.0053                  0.0464                   29978               0.2678                 0.2378                 0.671573547   0.4927                          0.4964
#                   wisconsin    wi       199900               0                       0.1112                  19342                -0.1195                 -0.2534                 114.5                 0.09047619               -0.045833333             4276              0.3346               -0.1502              116                   -0.1212                  -0.0645                  2180                0.0771                 -0.2236                12968                 2.6799                   5.0854                   114.9941711                          0.0109                                  0.0758                                  1722               -0.0023               0.0204                284023.8134           0.0141                   0.0926                   32310               0.2675                 0.1524                 0.670458071   0.51                            0.5882
#                   south dakota sd       226200               0.0053                  0.0521                  3140                 -0.0904                 0.1127                  84                    0.105263158              -0.01754386              832               0.4054               0.1492               28                    0.75                     0.1667                   324                 0.08                   0.1571                 428                   2.7876                   4.0952                   113.1014287                          0.0023                                  0.0563                                  1969.5             -0.0073               -0.0148               288747.4227           0.0107                   0.0389                   3568                8E-04                  0.2278                 0.136305732   0.1036                          0.1065
#
# [2246 rows x 1 columns]

# %%
for col in monthly_state.columns:
    print(col)
# Out:
# Metrics_State_History

# %%
monthly_state.to_csv("../Output/Monthly_Metrics_By_State.csv")

# %% [markdown]
# # Monthly Metrics by Zip

# %%
monthly_zip = pd.read_csv("../Dataset/Monthly_Inventory/Historical/Metrics_Zip_History.csv")
monthly_zip
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-57a167596ba9> in <module>
# ----> 1 monthly_zip = pd.read_csv("../Dataset/Monthly_Inventory/Historical/Metrics_Zip_History.csv")
#       2 monthly_zip
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File ../Dataset/Monthly_Inventory/Historical/Metrics_Zip_History.csv does not exist: '../Dataset/Monthly_Inventory/Historical/Metrics_Zip_History.csv'

# %%
for col in monthly_zip.columns:
    print(col)

# %%
monthly_zip.to_csv("../Output/Monthly_Metrics_By_Zip.csv")

# %% [markdown]
# # Weekly Metrics by Country

# %%
weekly_country = pd.read_csv("../Dataset/Weekly_Inventory/weekly_by_country.csv")
weekly_country
# Out:
#     week_end_date geo_country median_listing_price_yy active_listing_count_yy  \
# 0        9/4/2021         usa                    8.3%                  -23.6%
# 1       8/28/2021         usa                    8.6%                  -23.6%
# 2       8/21/2021         usa                    8.6%                  -24.7%
# 3       8/14/2021         usa                    8.6%                  -26.1%
# 4        8/7/2021         usa                    8.6%                  -27.8%
# ..            ...         ...                     ...                     ...
# 214     7/29/2017         usa                    8.1%                   -9.8%
# 215     7/22/2017         usa                    7.7%                   -9.9%
# 216     7/15/2017         usa                    7.7%                   -9.5%
# 217      7/8/2017         usa                    7.7%                  -10.3%
# 218      7/1/2017         usa                    8.1%                  -10.2%
#
#      median_days_on_market_by_day_yy median_days_on_market_yy  \
# 0                                -12                   -21.8%
# 1                                -15                   -26.8%
# 2                                -17                   -30.4%
# 3                                -18                   -32.1%
# 4                                -17                   -30.4%
# ..                               ...                      ...
# 214                               -6                    -8.3%
# 215                               -6                    -8.5%
# 216                               -4                    -5.8%
# 217                               -4                    -5.9%
# 218                               -4                    -6.0%
#
#     new_listing_count_yy new_listing_share_yy price_reduced_count_yy  \
# 0                  -8.2%                 2.0%                 -11.9%
# 1                   1.2%                 3.0%                 -10.2%
# 2                   1.8%                 3.3%                  -9.0%
# 3                   5.8%                 4.0%                 -11.4%
# 4                   2.9%                 4.0%                 -14.1%
# ..                   ...                  ...                    ...
# 214                 3.5%                 0.9%                  -0.7%
# 215                 3.4%                 1.0%                  -0.4%
# 216                 3.3%                 1.0%                  -0.4%
# 217                -2.3%                 0.6%                  -7.8%
# 218                -0.1%                 0.8%                  -1.7%
#
#     price_reduced_share_yy
# 0                     0.7%
# 1                     0.7%
# 2                     0.9%
# 3                     0.8%
# 4                     0.7%
# ..                     ...
# 214                   0.5%
# 215                   0.5%
# 216                   0.5%
# 217                   0.1%
# 218                   0.5%
#
# [219 rows x 10 columns]

# %%
for col in weekly_country.columns:
    print(col)
# Out:
# week_end_date
# geo_country
# median_listing_price_yy
# active_listing_count_yy
# median_days_on_market_by_day_yy
# median_days_on_market_yy
# new_listing_count_yy
# new_listing_share_yy
# price_reduced_count_yy
# price_reduced_share_yy

# %%
weekly_country.to_csv("../Output/Weekly_Metrics_By_Country.csv")

# %% [markdown]
# # Weekly Metrics by Metro

# %%
weekly_metro = pd.read_csv("../Dataset/Weekly_Inventory/weekly_by_metro.csv")
weekly_metro
# Out:
#       week_end_date  cbsa_code                                   cbsa_title  \
# 0          9/4/2021      35620        new york-newark-jersey city, ny-nj-pa
# 1          9/4/2021      31080           los angeles-long beach-anaheim, ca
# 2          9/4/2021      16980           chicago-naperville-elgin, il-in-wi
# 3          9/4/2021      19100              dallas-fort worth-arlington, tx
# 4          9/4/2021      37980  philadelphia-camden-wilmington, pa-nj-de-md
# ...             ...        ...                                          ...
# 21895      7/1/2017      16860                           chattanooga, tn-ga
# 21896      7/1/2017      38860                  portland-south portland, me
# 21897      7/1/2017      20500                       durham-chapel hill, nc
# 21898      7/1/2017      44060                   spokane-spokane valley, wa
# 21899      7/1/2017      27140                                  jackson, ms
#
#        hh_rank median_listing_price_yy active_listing_count_yy  \
# 0            1                   -2.4%                  -13.4%
# 1            2                   -3.5%                  -21.9%
# 2            3                   -5.4%                  -18.7%
# 3            4                   10.1%                  -34.7%
# 4            5                   -7.0%                   -1.8%
# ...        ...                     ...                     ...
# 21895       96                   12.6%                  -17.5%
# 21896       97                    6.1%                  -21.6%
# 21897       98                    8.1%                  -17.2%
# 21898       99                   16.0%                  -13.4%
# 21899      100                   11.1%                   -0.7%
#
#        median_days_on_market_by_day_yy median_days_on_market_yy  \
# 0                                    0                     0.0%
# 1                                   -2                    -4.1%
# 2                                   -3                    -7.1%
# 3                                  -12                   -25.5%
# 4                                    2                     4.4%
# ...                                ...                      ...
# 21895                               -4                    -6.3%
# 21896                              -14                   -19.7%
# 21897                               -3                    -4.4%
# 21898                              -12                   -24.0%
# 21899                               -2                    -2.6%
#
#       new_listing_count_yy new_listing_share_yy price_reduced_count_yy  \
# 0                   -38.6%                -2.2%                 -25.5%
# 1                   -27.1%                -0.8%                 -32.6%
# 2                   -15.2%                 0.5%                 -17.0%
# 3                    -3.8%                 5.2%                 -37.6%
# 4                    -6.8%                -0.6%                   4.4%
# ...                    ...                  ...                    ...
# 21895                -8.6%                 0.7%                    NaN
# 21896               -10.1%                 1.0%                    NaN
# 21897               -20.9%                -0.4%                    NaN
# 21898                16.0%                 2.7%                    NaN
# 21899                -7.4%                -0.3%                    NaN
#
#       price_reduced_share_yy
# 0                      -0.4%
# 1                      -0.6%
# 2                       0.1%
# 3                      -0.8%
# 4                       0.5%
# ...                      ...
# 21895                   0.3%
# 21896                   0.4%
# 21897                   0.8%
# 21898                   1.8%
# 21899                   0.2%
#
# [21900 rows x 12 columns]

# %%
for col in weekly_metro.columns:
    print(col)
# Out:
# week_end_date
# cbsa_code
# cbsa_title
# hh_rank
# median_listing_price_yy
# active_listing_count_yy
# median_days_on_market_by_day_yy
# median_days_on_market_yy
# new_listing_count_yy
# new_listing_share_yy
# price_reduced_count_yy
# price_reduced_share_yy

# %%
weekly_metro.to_csv("../Output/Weekly_Metrics_By_Metro.csv")
